# %%
import re
import pandas as pd
# import swifter
import numpy as np
import spacy
import pickle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-215c0b5cb043> in <module>
#       3 # import swifter
#       4 import numpy as np
# ----> 5 import spacy
#       6 import pickle
#
# ModuleNotFoundError: No module named 'spacy'

# %%
nlp = spacy.load('en_core_web_sm')
df = pd.read_csv('../data/my-ingredients.csv')

# %%
def change_meta_to_comma_separated(s):
    s = s.replace('[', '')
    s = s.replace(']', '')
    s = s.replace('"', '')
    return s

df['meta'] = df['meta'].apply(change_meta_to_comma_separated)

# %%
df.iloc[50:,:].head(50)
# df.info()
# Out:
#                 name                                           original  \
# 50            pepper                                1/2 teaspoon pepper
# 51      phyllo dough                              8 sheets phyllo dough
# 52    ricotta cheese                             1 pound ricotta cheese
# 53              salt                                  1/2 teaspoon salt
# 54           spinach         2 pounds spinach, chopped and squeezed dry
# 55    frozen spinach  1 (10 ounce) package frozen chopped spinach, t...
# 56            garlic                            2 cloves garlic, minced
# 57      ground cumin                            1 teaspoon ground cumin
# 58        mayonnaise                                 1/2 cup mayonnaise
# 59             onion                                 1 cup minced onion
# 60   red bell pepper                       1 cup minced red bell pepper
# 61              salt                                  1/2 teaspoon salt
# 62        sour cream                                 1/2 cup sour cream
# 63    cayenne pepper               big pinch of chile or cayenne pepper
# 64              eggs                                       6 large eggs
# 65             leeks                                   2 x medium leeks
# 66            nutmeg                                       whole nutmeg
# 67   parmesan cheese                                    Parmesan cheese
# 68   salt and pepper                     salt and freshly-ground pepper
# 69     salted butter                  2 tbsp butter, salted or unsalted
# 70           spinach                                2 lbs fresh spinach
# 71        whole milk                                  2 cups whole milk
# 72     baking powder                               3 tsps baking powder
# 73            butter            1 oz butter + a little bit of olive oil
# 74              eggs                                             3 eggs
# 75             flour                    1/2 + 2 Tbsps all-purpose flour
# 76              milk                             1/2 cup luke warm milk
# 77         mushrooms                             1 cup sliced mushrooms
# 78            nutmeg                                     1/4 tsp nutmeg
# 79   parmesan cheese  1/2 cup any cheese you have at hand. It can be...
# 80            pepper                                     1/2 tsp pepper
# 81              salt                                         1 tsp salt
# 82      sesame seeds                              2-4 tsps sesame seeds
# 83           spinach                                1 bag fresh spinach
# 84          tomatoes                             1 cup chopped tomatoes
# 85     vegetable oil                              1/4 cup vegetable oil
# 86       white onion                               1/4 of a white onion
# 87            butter                                      2 tbsp butter
# 88            chives                                 Chives to decorate
# 89             cream                                              Cream
# 90      fleur de sel                                Fleur de sel on top
# 91            pepper                                             Pepper
# 92          potatoes                                       3 x potatoes
# 93          sea salt                                           Sea salt
# 94           spinach                                300 g fresh spinach
# 95   vegetable broth        Vegetable broth, enough to cover vegetables
# 96     bamboo shoots                1/4 cup tinned bamboo shoot, sliced
# 97        dry sherry                     1 tablespoon medium-dry sherry
# 98  fresh gingerroot     2 slices peeled fresh gingerroot, quarter-size
# 99      garlic clove     1 large garlic clove, sliced in two lengthwise
#
#     amount        unit                            meta
# 50    0.50    teaspoon
# 51    8.00      sheets
# 52    1.00       pound
# 53    0.50    teaspoon
# 54    2.00      pounds                     dry,chopped
# 55   10.00       ounce           frozen,thawed,chopped
# 56    2.00      cloves                          minced
# 57    1.00    teaspoon
# 58    0.50         cup
# 59    1.00         cup                          minced
# 60    1.00         cup                      red,minced
# 61    0.50    teaspoon
# 62    0.50         cup                            sour
# 63    1.00       pinch
# 64    6.00         NaN                           large
# 65    2.00         NaN                          medium
# 66    2.00    servings                           whole
# 67    2.00    servings
# 68    2.00    servings                  freshly-ground
# 69    2.00        tbsp                 unsalted,salted
# 70    2.00         lbs                           fresh
# 71    2.00        cups                           whole
# 72    3.00        tsps
# 73    1.00          oz
# 74    3.00         NaN
# 75    0.50         NaN                     all-purpose
# 76    0.50         cup
# 77    1.00         cup                          sliced
# 78    0.25         tsp
# 79    0.50         cup                          canned
# 80    0.50         tsp
# 81    1.00         tsp
# 82    2.00        tsps
# 83    1.00         bag                           fresh
# 84    1.00         cup                         chopped
# 85    0.25         cup
# 86    0.25         NaN                           white
# 87    2.00        tbsp
# 88    1.00     serving
# 89    1.00     serving
# 90    1.00     serving
# 91    1.00     serving
# 92    3.00         NaN
# 93    1.00     serving
# 94  300.00           g                           fresh
# 95    1.00     serving             to cover vegetables
# 96    0.25         cup                   tinned,sliced
# 97    1.00  tablespoon
# 98    2.00      slices                    fresh,peeled
# 99    1.00         NaN  large,sliced in two lengthwise

# %%
# Helpers
def is_punctuation(s):
    return s in ('(', ')', 
                 '[', ']',
                 '!', '.', 
                 ',', '&',
                 '*')
def is_number(s):
    try:
        float(s)
        return True
    except:
        return False

def fractions_to_floats(line):
    """ Change all fractions to floats """
    has_two_fractions = re.compile(r'(\d+)\s+(\d+)/(\d+)') # i.e. 1 1/8 => 1.13
    has_one_fraction = re.compile(r'(\d+)/(\d+)')          # i.e. 1/2   => 1.5
    one_number = re.compile(r'\d+')                        # i.e. 16, 2 => 16.0, 2.0

    def has_two_handler(n):
        fraction = float(n.group(2)) / float(n.group(3))
        num = float(n.group(1)) + fraction
        return str(round(num, 2))

    def has_one_handler(n):
        fraction = float(n.group(1)) / float(n.group(2))
        return str(round(fraction, 2))

    def one_number_handler(n):
        return str(n.group(0) + '.0')

    if has_two_fractions.search(line):
        return has_two_fractions.sub(has_two_handler, line)
    elif has_one_fraction.search(line):
        return has_one_fraction.sub(has_one_handler, line)
    elif one_number.search(line):
        return one_number.sub(one_number_handler, line)
    else:
        return line

# %%
def process_original_string(string):
    doc = nlp(string)
    valid_words = [token for token in doc if not token.is_stop]
    lemma = [0] * len(valid_words)
    pos = [0] * len(valid_words)
    tag = [0] * len(valid_words)
    is_alpha = [0] * len(valid_words)
    is_num = [0] * len(valid_words)
    for i,token in enumerate(valid_words):
        lemma[i] = token.lemma_
        pos[i] = token.pos_
        tag[i] = token.tag_
        is_alpha[i] = token.is_alpha
        is_num[i] = is_number(token.lemma_)
    return {
        'lemma': lemma,
        'pos': pos,
        'tag': tag,
        'is_alpha': is_alpha,
        'is_num': is_num,
    }

def get_lemma(s):
    if not s or s is None or type(s) != str:
        return []
    return [token.lemma_ for token in nlp(s)]

def get_labels(row, processed_original):
    name = get_lemma(row['name'])
    amount = row['amount']
    unit = get_lemma(row['unit'])
    meta = get_lemma(row['meta'])
    # Assemble sent for each word by adding label
    labels = [0] * len(processed_original['lemma'])
    for i,word in enumerate(processed_original['lemma']):
        if is_punctuation(word):
            labels[i] = 'PUNCTUATION'
        elif word in name:
            labels[i] = 'NAME'
        elif is_number(word) and float(word) == float(amount):
            labels[i] = 'QUANTITY'
        elif word in unit:
            labels[i] = 'UNIT'
        elif word in meta:
            labels[i] = 'COMMENT'
        else:
            labels[i] = 'OTHER'
    return labels
    
def get_sents(row):
    processed_row = process_original_string(fractions_to_floats(row['original']))
    labels = get_labels(row, processed_row)
    processed_row['label'] = labels
    return processed_row

# %%
sents = df.swifter.apply(get_sents, axis=1)
sents.to_pickle('../data/processed-my-ingredients.pickle')
# Out:
# Pandas Apply: 100%|██████████| 115315/115315 [1:05:30<00:00, 29.34it/s]

# %%
sents = pd.read_pickle('../data/processed-my-ingredients.pickle')

# Sents to Features
def sents_to_features(sents):
    features = []
    labels = []
    for token in sents:
        curr_feature = []
        curr_labels = []
        for i in range(len(token['lemma'])):
            curr_feature.append({
                'word': token['lemma'][i],
                'pos': token['pos'][i],
                'tag': token['tag'][i],
                'is_alpha': token['is_alpha'][i],
                'is_num': token['is_num'][i],
                'prev_pos': token['pos'][i-1] if i-1 >= 0 else '',
                'prev_tag': token['tag'][i-1] if i-1 >= 0 else '',
                'prev_num': token['is_num'][i-1] if i-1 >= 0 else '',
                'next_pos': token['pos'][i+1] if i+1 < len(token) else '',
                'next_tag': token['tag'][i+1] if i+1 < len(token) else '',
                'next_num': token['is_num'][i+1] if i+1 < len(token) else '',
            })
            curr_labels.append(token['label'][i])
        features.append(curr_features)
        labels.append(curr_labels)
    return features, labels

final_data = sents_to_features(sents)
pickle.dump(final_data, '../data/features-my-ingredients.pickle')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d51c859aa2bf> in <module>
# ----> 1 sents = pd.read_pickle('../data/processed-my-ingredients.pickle')
#       2
#       3 # Sents to Features
#       4 def sents_to_features(sents):
#       5     features = []
#
# NameError: name 'pd' is not defined
